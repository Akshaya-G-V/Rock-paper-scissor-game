# %%
import random
import time

# %%
# With Pattern printing
d={1:'Rock',2:'Paper',3:'Scissor'}
print('Rules of the game: \n1 is Rock \n2 is Paper \n3 is Scissor \nRock beats scissor \nPaper beats rock \nScissor beats paper')
print()
while True:

    person=int(input('Enter your choice:'))
    computer=random.randint(1,3)
    if person in d.keys():
        print('Displaying result in')
        time.sleep(1)
        print(3)
        time.sleep(1)
        print(2)
        time.sleep(1)
        print(1)
        print()
        p=d[person]
    
    while person>3 or person<1:
        person=int(input('Enter valid choice:'))
        print('\n1 is Rock \n2 is Paper \n3 is Scissor')
    
    while person!=computer:
        if computer in d.keys():
            c=d[computer]
        
        if (person==1 and computer==3) or (person==2 and computer==1) or (person==3 and computer==2):
            r='You won'
            break
        else:
            r='Computer won'
            break
            
    if person==computer:
        r='Looks like you and the computer chose. It is a tie'
        
    for i in range(10):
        for j in range(40):
            if i == 0 or i == 9 or j == 0 or j == 39:
                print('*', end=' ')
            elif i >= 2 and i <= 8 and j >= 2 and j <= 12:
                if (i == 4 and j == 4):
                    print('\tYou have chosen',p, '\n\t\tComputer has chosen',c, '\n\t\t',r,end='')
                else:
                    print(" ", end=' ')
            else:
                print(" ", end=' ')

        print()    
    
    
        
    print('Do you want to play again? Y/N \nY-yes \nN-no')
    reply=input('Enter your reply:').lower()
    print()
    while reply not in ['y','n']:
        reply=input('Enter your reply:').lower()
    
    if reply=='n':
        break
        
        
        
print('Thanks for playing!')
# Out:
# Rules of the game:
# 1 is Rock
# 2 is Paper
# 3 is Scissor
# Rock beats scissor
# Paper beats rock
# Scissor beats paper
#
# Enter your choice:2
# Displaying result in
# 3
# 2
# 1
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# *                                                                             *
# *                                                                             *
# *                                                                             *
# *       	You have chosen Paper
# 		Computer has chosen Scissor
# 		 Computer won                                                                    *
# *                                                                             *
# *                                                                             *
# *                                                                             *
# *                                                                             *
# ...
